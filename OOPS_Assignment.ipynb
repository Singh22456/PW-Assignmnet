# %%
#Q1. What is Object-Oriented Programming (OOP)?
#A. A paradigm that models software as interacting objects containing state (attributes) and behavior (methods). Core ideas: encapsulation, abstraction, inheritance, polymorphism.

# %%
#Q2. What is a class in OOP?
#A. A blueprint for creating objects. It defines shared attributes and methods.
'''
class Car:
    def __init__(self, make): self.make = make
'''

# %%
#Q3. What is an object in OOP?
#A. An instance of a class with its own data.
'''
c = Car("Tesla")  # c is an object
'''

# %%
#Q4. What is the difference between abstraction and encapsulation?
#A. 	Abstraction expose essentials, hide unnecessary details (e.g., a clean API). Encapsulation keep data + methods together and control access (e.g., properties, “private” attrs).

# %%
#Q5. What are dunder methods in Python?
#A. “Magic” methods starting/ending with __ that hook into Python’s syntax/ops: __init__, __repr__, __len__, __iter__, __add__, context managers __enter__/__exit__, etc.

# %%
#Q6. Explain the concept of inheritance in OOP.
#A. A class (subclass) derives from another (base) to reuse/extend behavior.
'''
class EV(Car):
    def charge(self): ...
'''

# %%
#Q7. What is polymorphism in OOP?
#A. Same interface, different implementations. Works via overriding and duck typing.
'''
for a in animals: a.speak()  # each type handles speak()
'''

# %%
#Q8. How is encapsulation achieved in Python?
#A. Conventions + tools: single underscore _x (internal), name-mangling __x, and properties to validate/control access. Also modules/packages limit what’s exported via __all__.

# %%
#Q9. What is a constructor in Python?
#A. __init__(self, ...) initializes an already-created instance. Creation itself happens in __new__ (rarely customized, mostly for immutables).

# %%
#Q10. What are class and static methods in Python?
'''
A.	•	@classmethod: receives cls; can access/modify class state; often used as alternative constructors.
	  •	@staticmethod: no self/cls; utility function namespaced in the class.
'''

# %%
#Q11. What is method overloading in Python?
#A. No true compile-time overloading. Achieve similar behavior with default args, *args/**kwargs, type checks, or functools.singledispatch (for functions).

# %%
#Q12.  What is method overriding in OOP?
#A. A subclass provides a new implementation of a base method (same name/signature). Use super() to extend base behavior.

# %%
#Q13. What is a property decorator in Python?
#A. @property turns method access into attribute syntax with optional setters/deleters—great for validation and read-only fields.
'''
class User:
    def __init__(self, age): self._age = age
    @property
    def age(self): return self._age
    @age.setter
    def age(self, v):
        if v < 0: raise ValueError
        self._age = v
'''

# %%
#Q14. Why is polymorphism important in OOP?
#A. It enables flexible, extensible code: functions operate on abstract interfaces, not concrete types—improves testability and reduces coupling.

# %%
#Q15. What is an abstract class in Python?
#A. A class that can’t be instantiated and may define abstract methods. Use abc.ABC + @abstractmethod.
'''
from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self): ...
'''

# %%
#Q16. What are the advantages of OOP?
#A. Modularity, code reuse, clearer modeling of real-world domains, easier maintenance, extensibility via inheritance/composition, and polymorphic APIs.

# %%
#Q17. What is the difference between a class variable and an instance variable?
#A. Class variable shared across all instances. Instance variable unique per object (self.x). Be careful with mutable class variables (they’re shared!).

# %%
#Q18.  What is multiple inheritance in Python?
#A. A class inherits from multiple bases. Python resolves attribute lookup via MRO (C3 linearization) to avoid ambiguity.
#Eg: class X(A, B): pass

# %%
#Q19. Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.
'''A. 	•	__repr__: unambiguous, for developers; ideally a valid constructor string.
	    •	__str__: readable, for end users. print(obj) calls __str__, fallback to __repr__.'''

# %%
#Q20. What is the significance of the ‘super()’ function in Python?
'''A. Access next class in MRO—lets you call parent implementations cooperatively (crucial with multiple inheritance).
Eg: def __init__(self): super().__init__()'''

# %%
#Q21.  What is the significance of the __del__ method in Python?
#A. Finalizer called when object is about to be garbage-collected. Unreliable timing; avoid for resource cleanup—prefer context managers (with) or try/finally.

# %%
#Q22. What is the difference between @staticmethod and @classmethod in Python?
'''
A. 	•	staticmethod(f): plain function in class namespace; no implicit first arg.
	  •	classmethod(f): receives cls; can modify class state and create alternative constructors.
'''

# %%
#Q23. How does polymorphism work in Python with inheritance?
#A. Subclasses override base methods; code written against the base type transparently works with any subclass. Combined with duck typing, explicit inheritance isn’t strictly required.

# %%
#Q24. What is method chaining in Python OOP?
'''
A. Return self (or a new object) from mutator methods so calls can be chained.
E.g : builder.set_a(1).set_b(2).build()
'''

# %%
#Q25.  What is the purpose of the __call__ method in Python?
'''
A. Makes an instance callable like a function; useful for function objects, configurable processors, or stateful callbacks.
E.g:
class Adder:
    def __init__(self, n): self.n = n
    def __call__(self, x): return x + self.n
Adder(5)(10)  # 15
'''

# %% [markdown]
# **PRATICAL QUESTION**

# %%
#Q1. Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".
# Parent class
class Animal:
    def speak(self):
        print("This animal makes a sound.")

# Child class
class Dog(Animal):
    def speak(self):
        print("Bark!")

# Example usage
a = Animal()
a.speak()

d = Dog()
d.speak()
# Out:
# This animal makes a sound.
# Bark!

# %%
#Q2. Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.
from abc import ABC, abstractmethod
import math

# Abstract class
class Shape(ABC):

    @abstractmethod
    def area(self):
        pass

# Derived class - Circle
class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

# Derived class - Rectangle
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Example usage
circle = Circle(5)
rectangle = Rectangle(4, 6)

print("Area of Circle:", circle.area())
print("Area of Rectangle:", rectangle.area())
# Out:
# Area of Circle: 78.53981633974483
# Area of Rectangle: 24

# %%
#Q3. Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further derive a class ElectricCar that adds a battery attribute.
# Base class
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def display_type(self):
        print("Vehicle Type:", self.vehicle_type)


# Derived class 1
class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def display_brand(self):
        print("Car Brand:", self.brand)


# Derived class 2 (Multi-level inheritance)
class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

    def display_info(self):
        print(f"Electric Car Info:\nType: {self.vehicle_type}\nBrand: {self.brand}\nBattery: {self.battery_capacity} kWh")


# Example usage
e_car = ElectricCar("Four Wheeler", "Tesla", 75)
e_car.display_info()
# Out:
# Electric Car Info:
# Type: Four Wheeler
# Brand: Tesla
# Battery: 75 kWh

# %%
#Q4. Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.
# Base class
class Bird:
    def fly(self):
        print("Some birds can fly, some cannot.")


# Derived class 1
class Sparrow(Bird):
    def fly(self):
        print("Sparrow flies high in the sky.")


# Derived class 2
class Penguin(Bird):
    def fly(self):
        print("Penguins cannot fly, but they swim well.")


# Function showing polymorphism
def bird_fly_test(bird):
    bird.fly()


# Example usage
sparrow = Sparrow()
penguin = Penguin()

bird_fly_test(sparrow)   # Output: Sparrow flies high in the sky.
bird_fly_test(penguin)   # Output: Penguins cannot fly, but they swim well.
# Out:
# Sparrow flies high in the sky.
# Penguins cannot fly, but they swim well.

# %%
#Q5. Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes balance and methods to deposit, withdraw, and check balance.
# Class demonstrating encapsulation
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.__balance = balance  # private attribute

    # Deposit money
    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"₹{amount} deposited successfully.")
        else:
            print("Invalid deposit amount.")

    # Withdraw money
    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"₹{amount} withdrawn successfully.")
        else:
            print("Insufficient balance or invalid amount.")

    # Check balance
    def get_balance(self):
        print(f"Current balance: ₹{self.__balance}")


# Example usage
account = BankAccount("Brahmjot", 5000)
account.deposit(2000)
account.withdraw(1500)
account.get_balance()

# Trying to access private variable directly
print(account.__dict__)  # To show encapsulated attribute names
# Out:
# ₹2000 deposited successfully.
# ₹1500 withdrawn successfully.
# Current balance: ₹5500
# {'owner': 'Brahmjot', '_BankAccount__balance': 5500}

# %%
#Q6. Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play().
# Base class
class Instrument:
    def play(self):
        print("The instrument is being played.")


# Derived class 1
class Guitar(Instrument):
    def play(self):
        print("Strumming the guitar strings")


# Derived class 2
class Piano(Instrument):
    def play(self):
        print("Playing the piano keys")


# Function demonstrating runtime polymorphism
def perform(instrument):
    instrument.play()


# Example usage
guitar = Guitar()
piano = Piano()

perform(guitar)
perform(piano)
# Out:
# Strumming the guitar strings
# Playing the piano keys

# %%
#Q7. Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.
class MathOperations:
    # Class variable
    operation_name = "Basic Math Operations"

    # Class method
    @classmethod
    def add_numbers(cls, a, b):
        print(f"Performing: {cls.operation_name}")
        return a + b

    # Static method
    @staticmethod
    def subtract_numbers(a, b):
        return a - b


# Example usage
sum_result = MathOperations.add_numbers(10, 5)
diff_result = MathOperations.subtract_numbers(10, 5)

print("Sum:", sum_result)
print("Difference:", diff_result)
# Out:
# Performing: Basic Math Operations
# Sum: 15
# Difference: 5

# %%
#Q8. Implement a class Person with a class method to count the total number of persons created.
class Person:
    # Class variable to count persons
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1  # Increment when a new object is created

    # Class method to access class variable
    @classmethod
    def total_persons(cls):
        return cls.count


# Example usage
p1 = Person("Alice")
p2 = Person("Bob")
p3 = Person("Charlie")

print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %%
#Q9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".
class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    # Overriding __str__ to display custom output
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"


# Example usage
f1 = Fraction(3, 4)
f2 = Fraction(5, 2)

print(f1)
print(f2)
# Out:
# 3/4
# 5/2

# %%
#Q10. Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    # Overloading the + operator
    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    # Overriding __str__ for clean output
    def __str__(self):
        return f"Vector({self.x}, {self.y})"


# Example usage
v1 = Vector(2, 3)
v2 = Vector(4, 5)

v3 = v1 + v2  # Calls v1.__add__(v2)

print(v1)
print(v2)
print(v3)
# Out:
# Vector(2, 3)
# Vector(4, 5)
# Vector(6, 8)

# %%
#Q11. Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")


# Example usage
p1 = Person("Brahmjot", 21)
p1.greet()
# Out:
# Hello, my name is Brahmjot and I am 21 years old.

# %%
#Q12. Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = grades  # list of grades

    def average_grade(self):
        if len(self.grades) == 0:
            return 0
        return sum(self.grades) / len(self.grades)


# Example usage
s1 = Student("Brahmjot", [85, 90, 78, 92])
s2 = Student("Udaibir", [70, 80, 75])

print(f"{s1.name}'s average grade: {s1.average_grade():.2f}")
print(f"{s2.name}'s average grade: {s2.average_grade():.2f}")
# Out:
# Brahmjot's average grade: 86.25
# Udaibir's average grade: 75.00

# %%
#Q13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.
class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    # Method to set dimensions
    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    # Method to calculate area
    def area(self):
        return self.length * self.width


# Example usage
rect = Rectangle()
rect.set_dimensions(10, 5)
print("Area of Rectangle:", rect.area())
# Out:
# Area of Rectangle: 50

# %%
#Q14. Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.
# Base class
class Employee:
    def __init__(self, name, hours_worked, hourly_rate):
        self.name = name
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate


# Derived class
class Manager(Employee):
    def __init__(self, name, hours_worked, hourly_rate, bonus):
        super().__init__(name, hours_worked, hourly_rate)
        self.bonus = bonus

    # Overriding the method to include bonus
    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus


# Example usage
emp = Employee("Alice", 40, 500)
mgr = Manager("Brahmjot", 45, 600, 5000)

print(f"{emp.name}'s Salary: ₹{emp.calculate_salary()}")
print(f"{mgr.name}'s Salary: ₹{mgr.calculate_salary()}")
# Out:
# Alice's Salary: ₹20000
# Brahmjot's Salary: ₹32000

# %%
#Q15. Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    # Method to calculate total price
    def total_price(self):
        return self.price * self.quantity


# Example usage
p1 = Product("Laptop", 60000, 2)
p2 = Product("Headphones", 1500, 3)

print(f"Total price of {p1.name}: ₹{p1.total_price()}")
print(f"Total price of {p2.name}: ₹{p2.total_price()}")
# Out:
# Total price of Laptop: ₹120000
# Total price of Headphones: ₹4500

# %%
#Q16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.
from abc import ABC, abstractmethod

# Abstract base class
class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass  # Abstract method — must be implemented by subclasses


# Derived class 1
class Cow(Animal):
    def sound(self):
        return "Moo"


# Derived class 2
class Sheep(Animal):
    def sound(self):
        return "Baa"


# Example usage
cow = Cow()
sheep = Sheep()

print("Cow sound:", cow.sound())
print("Sheep sound:", sheep.sound())
# Out:
# Cow sound: Moo
# Sheep sound: Baa

# %%
#Q17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    # Method to return formatted book info
    def get_book_info(self):
        return f"'{self.title}' by {self.author}, published in {self.year_published}."


# Example usage
book1 = Book("The Alchemist", "Paulo Coelho", 1988)
book2 = Book("Atomic Habits", "James Clear", 2018)

print(book1.get_book_info())
print(book2.get_book_info())
# Out:
# 'The Alchemist' by Paulo Coelho, published in 1988.
# 'Atomic Habits' by James Clear, published in 2018.

# %%
#Q18. Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms
# Base class
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

    def display_info(self):
        print(f"House located at {self.address}, priced at ₹{self.price}")


# Derived class
class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)  # Initialize attributes from the parent class
        self.number_of_rooms = number_of_rooms

    def display_info(self):
        print(f"Mansion located at {self.address}, priced at ₹{self.price}, with {self.number_of_rooms} rooms.")


# Example usage
house = House("123 Green Street", 5000000)
mansion = Mansion("45 Elite Avenue", 25000000, 10)

house.display_info()
mansion.display_info()
# Out:
# House located at 123 Green Street, priced at ₹5000000
# Mansion located at 45 Elite Avenue, priced at ₹25000000, with 10 rooms.
